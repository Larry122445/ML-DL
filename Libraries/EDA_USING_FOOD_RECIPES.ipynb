# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
'''
What data do we have?
What is the dimension of this data?
Are there any dependent variables?
What are the data types?
Missing data?
Duplicate data?
Correlations?
'''
df = pd.read_csv('https://raw.githubusercontent.com/softhints/Pandas-Exercises-Projects/main/data/food_recipes.csv', low_memory=False)

# %% [markdown]
# # Initial Analysis

# %%
df
# Out:
#                                            recipe_title  \
# 0     Roasted Peppers And Mushroom Tortilla Pizza Re...
# 1     Thakkali Gotsu Recipe | Thakkali Curry | Spicy...
# 2                  Spicy Grilled Pineapple Salsa Recipe
# 3        Karwar Style Dali Thoy Recipe - Toor dal Curry
# 4       Rajma Kofta In Milk And Poppy Seed Gravy Recipe
# ...                                                 ...
# 8004                   Zucchini and Carrot Pasta Recipe
# 8005  Hyderabadi Khatti Dal Recipe (Hyderabadi Tangy...
# 8006  Karwar Style Muga Ambat Recipe (Moong Sprouts ...
# 8007  Beetroot, Amla And Pudina Juice Recipe | Mint ...
# 8008  Chettinad Cauliflower Pepper Fry Recipe - Chet...
#
#                                                     url record_health  \
# 0     https://www.archanaskitchen.com/roasted-pepper...          good
# 1     https://www.archanaskitchen.com/tomato-gotsu-r...          good
# 2     https://www.archanaskitchen.com/spicy-grilled-...          good
# ...

# %%
df.head(1)
# Out:
#                                         recipe_title  \
# 0  Roasted Peppers And Mushroom Tortilla Pizza Re...
#
#                                                  url record_health  \
# 0  https://www.archanaskitchen.com/roasted-pepper...          good
#
#    vote_count    rating                                        description  \
# 0         434  4.958525   is a quicker version pizza to satisfy your cr...
#
#    cuisine  course        diet prep_time cook_time  \
# 0  Mexican  Dinner  Vegetarian      15 M      15 M
#
#                                          ingredients  \
# 0  Tortillas|Extra Virgin Olive Oil|Garlic|Mozzar...
#
#                                         instructions             author  \
# 0  To begin making the Roasted Peppers And Mushro...  Divya Shivaraman
#
#                                                 tags       category
# 0  Party Food Recipes|Tea Party Recipes|Mushroom ...  Pizza Recipes

# %%
df.sample(2)
# Out:
#                                            recipe_title  \
# 2063    Khatte Pudina Aloo Recipe - Tangy Mint Potatoes
# 1939  Turkish Chicken Gozleme Recipe-Stuffed Spinach...
#
#                                                     url record_health  \
# 2063  https://www.archanaskitchen.com/tangy-mint-pot...          good
# 1939  https://www.archanaskitchen.com/turkish-chicke...          good
#
#       vote_count   rating                                        description  \
# 2063         880  4.87500  No Onion No Garlic   are a crowd pleaser and p...
# 1939        3666  4.93317   is a delicious main course made in turkey. Th...
#
#              cuisine course            diet prep_time cook_time  \
# 2063          Indian  Lunch      Vegetarian      10 M      15 M
# 1939  Middle Eastern  Lunch  Non Vegeterian      10 M      45 M
#
#                                             ingredients  \
# 2063  Potatoes (Aloo)|Mint Leaves (Pudina)|Coriander...
# ...

# %% [markdown]
# # Dimensions And Dtypes Of dataFrame

# %%
df.shape
# Out:
# (8009, 16)

# %%
df.columns
# Out:
# Index(['recipe_title', 'url', 'record_health', 'vote_count', 'rating',
#        'description', 'cuisine', 'course', 'diet', 'prep_time', 'cook_time',
#        'ingredients', 'instructions', 'author', 'tags', 'category'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8009 entries, 0 to 8008
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   recipe_title   8009 non-null   object
#  1   url            8009 non-null   object
#  2   record_health  8009 non-null   object
#  3   vote_count     8009 non-null   int64
#  4   rating         8009 non-null   float64
#  5   description    7994 non-null   object
#  6   cuisine        7943 non-null   object
#  7   course         7854 non-null   object
#  8   diet           7858 non-null   object
#  9   prep_time      7979 non-null   object
#  10  cook_time      7979 non-null   object
#  11  ingredients    7997 non-null   object
#  12  instructions   8009 non-null   object
#  13  author         8009 non-null   object
#  14  tags           7930 non-null   object
#  15  category       8009 non-null   object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 1001.3+ KB

# %%
#insights
"""
rows = 8009
cols = 16
2 numeric cols
conversion for prep_time and cook _time
str to int
"""
df.dtypes
# Out:
# recipe_title      object
# url               object
# record_health     object
# vote_count         int64
# rating           float64
# description       object
# cuisine           object
# course            object
# diet              object
# prep_time         object
# cook_time         object
# ingredients       object
# instructions      object
# author            object
# tags              object
# category          object
# dtype: object

# %% [markdown]
# # Statistics - min, max, mean, percentile

# %% [markdown]
# Insights:
#
# mean value is close to 75%,
# no missing values,
# big difference between max and 75% percentile for vote_count - potential outliers

# %%
df.describe()
# Out:
#          vote_count       rating
# count   8009.000000  8009.000000
# mean    2268.004495     4.888621
# std     3683.156570     0.077467
# min       15.000000     3.175705
# 25%      494.000000     4.865031
# 50%     1050.000000     4.900553
# 75%     2487.000000     4.930000
# max    80628.000000     5.000000

# %% [markdown]
# Insights:
#
# 4 categorical columns - category, cuisine, diet and course
# 1 column with single value - record_health

# %%
df.describe(include='object')
# Out:
#                                              recipe_title  \
# count                                                8009
# unique                                               8009
# top     Roasted Peppers And Mushroom Tortilla Pizza Re...
# freq                                                    1
#
#                                                       url record_health  \
# count                                                8009          8009
# unique                                               8009             1
# top     https://www.archanaskitchen.com/roasted-pepper...          good
# freq                                                    1          8009
#
#                                            description cuisine course  \
# count                                             7994    7943   7854
# unique                                            7989      77     13
# top     If you like this recipe, try more recipes like  Indian  Lunch
# ...

# %%
df.diet.nunique()
# Out:
# 10

# %%
df.diet.unique()
# Out:
# array(['Vegetarian', 'High Protein Vegetarian', 'Non Vegeterian',
#        'No Onion No Garlic (Sattvic)', 'High Protein Non Vegetarian',
#        'Diabetic Friendly', 'Eggetarian', 'Vegan', 'Gluten Free', nan,
#        'Sugar Free Diet'], dtype=object)

# %%
df.diet.value_counts(dropna=False)
# Out:
# diet
# Vegetarian                      5478
# High Protein Vegetarian          792
# Non Vegeterian                   447
# Eggetarian                       391
# Diabetic Friendly                296
# High Protein Non Vegetarian      225
# NaN                              151
# No Onion No Garlic (Sattvic)      77
# Vegan                             71
# Gluten Free                       66
# Sugar Free Diet                   15
# Name: count, dtype: int64

# %% [markdown]
# """Insights:
#
# 10 unique values,
# categorical column,
# Vegetarian - is the most frequent value,
# 151 - missing values"""

# %% [markdown]
# # Data conversion in Pandas

# %% [markdown]
# replace M with empty string and fillna

# %%
df['cook_time'] = df['cook_time'].str.replace(' M', '').fillna(0).astype(int)
df['prep_time'] = df['prep_time'].str.replace(' M', '').fillna(0).astype(int)

# %% [markdown]
# # Expand nested column

# %%
df['ingredients'].str.split('|', expand=True).head().dropna(axis=1,inplace=True)

# %%
"""To find the most common 'ingredient' in the all recipes we can use the following steps:

split the column on separator "|"
expand=True - will expand data to DataFrame
melt() - transform DataFrame columns to rows - pairs of variable and value
count the values by .value_counts()
"""
df['ingredients'].str.split('|',expand=True).melt()['value'].value_counts()
# Out:
# value
# Salt                       5698
# Sunflower Oil              2241
# Garlic                     2227
# Turmeric powder (Haldi)    2221
# Onion                      2012
#                            ...
# नारीयल पानी                   1
# नारीयल का दूध                 1
# सिंघाड़े का आटा               1
# Black currant (dried)         1
# Corn chips                    1
# Name: count, Length: 1823, dtype: int64

# %% [markdown]
# # Visualization for Data Analysis

# %%
#missing values
df.isna()
# Out:
#       recipe_title    url  record_health  vote_count  rating  description  \
# 0            False  False          False       False   False        False
# 1            False  False          False       False   False        False
# 2            False  False          False       False   False        False
# 3            False  False          False       False   False        False
# 4            False  False          False       False   False        False
# ...            ...    ...            ...         ...     ...          ...
# 8004         False  False          False       False   False        False
# 8005         False  False          False       False   False        False
# 8006         False  False          False       False   False        False
# 8007         False  False          False       False   False        False
# 8008         False  False          False       False   False        False
#
#       cuisine  course   diet  prep_time  cook_time  ingredients  instructions  \
# ...

# %%
sns.heatmap(df.isna(),cmap='Greens')
# Out:
# <Axes: >

# %%
#missing values for last 3000 rows
sns.heatmap(df.tail(3000).isna(),cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# # Detect outliers

# %%
cols = ['vote_count', 'rating',  'prep_time', 'cook_time']
plt.figure(figsize=(20, 10))
sns.boxplot(data=df[cols], orient='h')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.show()

# %%
df[['prep_time', 'cook_time']].head(18).describe()
# Out:
#        prep_time  cook_time
# count  18.000000  18.000000
# mean   12.222222  22.388889
# std     4.608886  17.091928
# min     5.000000   0.000000
# 25%    10.000000  11.250000
# 50%    10.000000  20.000000
# 75%    15.000000  30.000000
# max    20.000000  60.000000

# %%
cols = ['prep_time', 'cook_time']
plt.figure(figsize=(20, 10))
sns.boxplot(data=df[cols].head(18), orient='h')
plt.set_title('Detecting Outliers Explained',fontsize=25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[161], line 4
#       2 plt.figure(figsize=(20, 10))
#       3 sns.boxplot(data=df[cols].head(18), orient='h')
# ----> 4 plt.set_title('Detecting Outliers Explained',fontsize=25)
#       5 plt.xticks(fontsize=25)
#       6 plt.yticks(fontsize=25)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'set_title'

# %%
df[cols].head(18)
# Out:
#     prep_time  cook_time
# 0          15         15
# 1          10         20
# 2          10          0
# 3           5         20
# 4          20         30
# 5          10         30
# 6          10          0
# 7          10         30
# 8          10         45
# 9          20         40
# 10          5         20
# 11         10         10
# 12         20          8
# 13         15         15
# 14         10         60
# 15         10          0
# 16         15         15
# 17         15         45
