# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
import seaborn as sns

# %%
sns.set()

# %%
names  =['preg','plas','pres','skin','test','mass','pedi','age','class']

# %%
dataset = pd.read_csv('C:\\Users\\ICT\\Desktop\\ML-DL\\Algorithms_from_Scratch\\DataPreparations\\pima-indians-diabetes.data.csv',names = names)

# %%
dataset
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %% [markdown]
# histogram

# %%
dataset.hist()
plt.subplots_adjust(hspace=0.5, wspace=0.5) # Adjust the horizontal and vertical spacing plt.show()
plt.show()

# %% [markdown]
# Density Plot

# %%
dataset.plot(kind = 'density',subplots=True,layout=(3,3),sharex=False)
plt.subplots_adjust(hspace=0.5, wspace=0.5) # Adjust the horizontal and vertical spacing plt.show()
plt.show()

# %% [markdown]
# Box and whisker

# %%
dataset.plot(kind = 'box',subplots=True,layout=(3,3),sharex=False,sharey=False)
plt.subplots_adjust(hspace=0.5, wspace=0.5) # Adjust the horizontal and vertical spacing plt.show()
plt.show()

# %% [markdown]
# correlations

# %%
import numpy as np

# %%
correlations = dataset.corr()
# plot correlation matrix
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,9,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
plt.show()

# %% [markdown]
# Scatter plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(dataset)
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()
